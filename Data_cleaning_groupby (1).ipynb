# %%
cd Downloads
# Out:
# [WinError 2] The system cannot find the file specified: 'Downloads'
# C:\Users\Administrator\Downloads

# %%
import pandas as pd

# %%
df = pd.read_csv('top-5000-youtube-channels-data-from-socialblade/data.csv')

# %%
df.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
# Rank             5000 non-null object
# Grade            5000 non-null object
# Channel name     5000 non-null object
# Video Uploads    5000 non-null object
# Subscribers      5000 non-null object
# Video views      5000 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
df['Subscribers'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f5a99f1ce303> in <module>()
# ----> 1 df['Subscribers'].astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ...

# %%
df.loc[df['Subscribers'] == '-- ']
# Out:
#          Rank Grade                        Channel name Video Uploads  \
# 17       18th   A+                      Vlad and Nikita            53
# 108     109th    A                               BIGFUN           373
# 115     116th    A         Bee Kids Games - Children TV           740
# 142     143rd    A                  ChiChi TV Siêu Nhân           421
# 143     144th    A                       MusicTalentNow          1487
# 152     153rd    A                       Family GamesTV           282
# 156     157th    A                              KH Show            31
# 175     176th    A                         LES BOYS TV2           116
# 180     181st    A                            BIBO TOYS           313
# 189     190th    A                         Kids Tv Show             8
# 192     193rd    A   Happy Funny Kids Toys Pretend Play           850
# 197     198th    A                   Learn Colors Keiki             6
# ...

# %%
(df.loc[df['Subscribers'] != '-- ']).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-20b99c68f695> in <module>()
# ----> 1 (df.loc[df['Subscribers'] != '-- ']).astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
# ...

# %%
import numpy as np

# %%
df.loc[df['Subscribers'] == '-- ', 'Subscribers'] = np.nan

# %%
df['Subscribers'].astype(float)
# Out:
# 0       18752951.0
# 1       61196302.0
# 2       19238251.0
# 3       31180559.0
# 4       32852346.0
# 5       17149705.0
# 6       11373567.0
# 7       12149206.0
# 8       16082927.0
# 9        2841811.0
# 10      33492951.0
# 11      39409726.0
# 12       7662886.0
# 13      18824912.0
# 14      15899764.0
# 15      11569723.0
# 16      15830098.0
# 17             NaN
# 18      23603062.0
# 19      17687229.0
# 20      11593509.0
# 21      23440427.0
# 22      11347420.0
# 23       2137907.0
# 24        712562.0
# 25      14469618.0
# 26      16924523.0
# 27      15836366.0
# 28       2902714.0
# 29        459906.0
#            ...
# 4970      885667.0
# 4971     2414713.0
# 4972      673787.0
# 4973      829870.0
# 4974     1436546.0
# 4975      150091.0
# 4976      229079.0
# 4977      638404.0
# 4978      106628.0
# 4979     1558006.0
# 4980     6532616.0
# 4981      158905.0
# 4982      647435.0
# 4983      219238.0
# 4984     2875705.0
# 4985      820381.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
# Rank             5000 non-null object
# Grade            5000 non-null object
# Channel name     5000 non-null object
# Video Uploads    5000 non-null object
# Subscribers      4613 non-null object
# Video views      5000 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
gt = pd.read_csv('gt.csv')

# %%
cd data_clean
# Out:
# C:\Users\Administrator\Downloads\data_clean

# %%
gt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 12 columns):
# Timestamp                     117 non-null object
# Entering Grade Level          117 non-null object
# District                      101 non-null float64
# Birth Month                   117 non-null object
# OLSAT Verbal Score            117 non-null object
# OLSAT Verbal Percentile       117 non-null object
# NNAT Non Verbal Raw Score     117 non-null object
# NNAT Non Verbal Percentile    117 non-null int64
# Overall Score                 117 non-null int64
# School Preferences            75 non-null object
# School Assigned               29 non-null object
# Will you enroll there?        71 non-null object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 11.0+ KB

# %%
gt.head()
# Out:
#             Timestamp Entering Grade Level  District Birth Month  \
# 0    4/8/2017 6:44:01                    1       6.0   September
# 1   4/7/2017 10:40:45                    K       NaN      August
# 2   4/7/2017 10:41:56                    1       NaN       March
# 3   4/7/2017 10:43:31                    K       NaN   September
# 4  4/10/2017 10:18:34                    K      22.0       April
#
#   OLSAT Verbal Score OLSAT Verbal Percentile NNAT Non Verbal Raw Score  \
# 0                 28                      99                        45
# 1                 25                      99                        39
# 2                 27                      96                        42
# 3                 23                      97                        40
# 4                 25                      98                        38
#
#    NNAT Non Verbal Percentile  Overall Score           School Preferences  \
# ...

# %%
gt.columns
# Out:
# Index(['Timestamp', 'Entering Grade Level', 'District', 'Birth Month',
#        'OLSAT Verbal Score', 'OLSAT Verbal Percentile',
#        'NNAT Non Verbal Raw Score', 'NNAT Non Verbal Percentile',
#        'Overall Score', 'School Preferences', 'School Assigned',
#        'Will you enroll there?'],
#       dtype='object')

# %%
gt['OLSAT Verbal Score'].astype(int)

#, 'OLSAT Verbal Percentile',
       #'NNAT Non Verbal Raw Score',
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-16f26b557e27> in <module>()
# ----> 1 gt['OLSAT Verbal Score'].astype(int)
#       2
#       3 #, 'OLSAT Verbal Percentile',
#       4        #'NNAT Non Verbal Raw Score',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
# ...

# %%
def str_cln(str1):
    if '/' in str1:
        return str1[:str1.find('/')]
    else:
        return str1

str_cln('24/30')
# Out:
# '24'

# %%
str_cln('24242')
# Out:
# '24242'

# %%
(gt['OLSAT Verbal Score'].apply(str_cln)).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-b3f7e04fe36e> in <module>()
# ----> 1 (gt['OLSAT Verbal Score'].apply(str_cln)).astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
# ...

# %%
for i in col_conv:
    gt[i] = gt[i].apply(cln)

def cln(str1):
    if str1.isnumeric():
        return int(str1)
    elif str1.find('/') != -1:
        return int(str1[:str1.find('/')])
    else:
        return np.nan

# %%
fifa = pd.read_csv('data.csv')
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa = fifa[['Nationality', 'Club', 'Age', 'Overall', 'Wage', 'Release Clause']]

# %%
fifa.groupby('Nationality')

# %%
len(fifa['Nationality'].unique())
# Out:
# 164

# %%
fifa.groupby('Nationality').mean()
# Out:
#                             Age    Overall
# Nationality
# Afghanistan           22.500000  61.000000
# Albania               24.025000  65.925000
# Algeria               27.050000  70.633333
# Andorra               28.000000  62.000000
# Angola                25.866667  67.600000
# Antigua & Barbuda     22.750000  62.500000
# Argentina             26.205977  68.572038
# Armenia               26.800000  69.000000
# Australia             24.406780  62.652542
# Austria               24.654362  64.916107
# Azerbaijan            26.000000  63.000000
# Barbados              27.666667  63.333333
# Belarus               28.750000  70.250000
# Belgium               24.334615  68.811538
# Belize                25.000000  60.000000
# Benin                 26.066667  67.466667
# Bermuda               27.500000  66.500000
# Bolivia               25.533333  65.666667
# Bosnia Herzegovina    26.000000  68.639344
# Botswana              20.000000  56.000000
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 6 columns):
# Nationality       18207 non-null object
# Club              17966 non-null object
# Age               18207 non-null int64
# Overall           18207 non-null int64
# Wage              18207 non-null object
# Release Clause    16643 non-null object
# dtypes: int64(2), object(4)
# memory usage: 853.5+ KB

# %%
fifa.head()
# Out:
#   Nationality                 Club  Age  Overall   Wage Release Clause
# 0   Argentina         FC Barcelona   31       94  €565K        €226.5M
# 1    Portugal             Juventus   33       94  €405K        €127.1M
# 2      Brazil  Paris Saint-Germain   26       92  €290K        €228.1M
# 3       Spain    Manchester United   27       91  €260K        €138.6M
# 4     Belgium      Manchester City   27       91  €355K        €196.4M

# %%
fifa['Wage'] = fifa['Wage'].apply(lambda x: x[1:-1])

# %%
fifa.loc[fifa['Wage'] == '', 'Wage'] = np.nan

# %%
fifa.loc[fifa['Wage'] == '', 'Wage']
# Out:
# Series([], Name: Wage, dtype: object)

# %%
fifa['Wage'] = fifa['Wage'].astype(float)

# %%
fifa['Release Clause'] = fifa['Release Clause'].apply(lambda x: x[1:-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-161-d5bb2aa4ac13> in <module>()
# ----> 1 fifa['Release Clause'] = fifa['Release Clause'].apply(lambda x: x[1:-1])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-161-d5bb2aa4ac13> in <lambda>(x)
# ----> 1 fifa['Release Clause'] = fifa['Release Clause'].apply(lambda x: x[1:-1])
#
# TypeError: 'float' object is not subscriptable

# %%
fifa['Release Clause']
# Out:
# 0        €226.5M
# 1        €127.1M
# 2        €228.1M
# 3        €138.6M
# 4        €196.4M
# 5        €172.1M
# 6        €137.4M
# 7          €164M
# 8        €104.6M
# 9        €144.5M
# 10       €127.1M
# 11       €156.8M
# 12        €90.2M
# 13         €111M
# 14       €121.3M
# 15       €153.5M
# 16       €160.7M
# 17       €165.8M
# 18       €123.3M
# 19       €113.7M
# 20       €105.6M
# 21         €111M
# 22        €62.7M
# 23       €119.3M
# 24        €44.6M
# 25       €166.1M
# 26       €137.3M
# 27       €126.4M
# 28           NaN
# 29       €105.4M
#           ...
# 18177      €193K
# 18178       €94K
# 18179      €119K
# 18180       €78K
# 18181      €109K
# 18182      €101K
# 18183        NaN
# 18184       €78K
# 18185       €88K
# 18186      €167K
# 18187       €66K
# 18188      €143K
# 18189      €125K
# 18190      €165K
# 18191      €119K
# 18192      €119K
# 18193       €99K
# 18194      €109K
# 18195      €153K
# 18196      €113K
# 18197       €88K
# ...

# %%
def clnr(str1):
    try:
        return str1[1:-1]
    except TypeError:
        pass

# %%
fifa['Release Clause'] = fifa['Release Clause'].apply(clnr)

# %%
fifa['Release Clause'] = fifa['Release Clause'].astype(float)

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 6 columns):
# Nationality       18207 non-null object
# Club              17966 non-null object
# Age               18207 non-null int64
# Overall           18207 non-null int64
# Wage              17966 non-null float64
# Release Clause    16643 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 853.5+ KB

# %%
aggregations = {'Age': 'mean',
                'Overall': 'mean',
                'Wage':{'Total Wage': 'sum',
                        'Avergae Wage': 'mean'},
                'Release Clause': 'mean'}
fifa.groupby(['Nationality', 'Club']).agg(aggregations)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:4658: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                                            Age    Overall       Wage  \
#                                           mean       mean Total Wage
# Nationality Club
# Afghanistan Notts County             21.000000  60.000000        2.0
#             Philadelphia Union       23.000000  59.000000        1.0
#             SV Meppen                26.000000  63.000000        1.0
#             Walsall                  20.000000  62.000000        1.0
# Albania     AC Ajaccio               22.000000  66.000000        2.0
#             Aalborg BK               21.000000  52.000000        1.0
#             Albacete BP              21.000000  67.000000       14.0
#             Atalanta                 25.000000  67.000000        8.0
# ...

# %%
fifa_dfs = {}
for group, data in fifa.groupby(['Nationality']):
    fifa_dfs[group] = data

# %%
ff1 =  fifa.groupby(['Nationality', 'Club']).agg(aggregations)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:4658: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
pd.read_csv
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-457ef2c312ee> in <module>()
# ----> 1 ff1.iloc['Afghanistan']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2093         # a single integer
#    2094         else:
# -> 2095             key = self._convert_scalar_indexer(key, axis)
#    2096
#    2097             if not is_integer(key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_scalar_indexer(self, key, axis)
# ...
